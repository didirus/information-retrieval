# %%
# SET UP
import pyndri
import pyndri.compat
import gensim
import copy
import logging
import time
import numpy as np
import logging
import sys
import collections
import io
from scipy import spatial
import pickle
tfidf_rankings = pickle.load(open("./tfidf_top.p", "rb")) # top 1000 rankings per query with tf-idf from Task 1
index = pyndri.Index('index/')

# %% [markdown]
# ### Parsing the query file
# You can parse the query file (`ap_88_89/topics_title`) using the following snippet:

# %%
def parse_topics(file_or_files,
                 max_topics=sys.maxsize, delimiter=';'):
    assert max_topics >= 0 or max_topics is None

    topics = collections.OrderedDict()

    if not isinstance(file_or_files, list) and \
            not isinstance(file_or_files, tuple):
        if hasattr(file_or_files, '__iter__'):
            file_or_files = list(file_or_files)
        else:
            file_or_files = [file_or_files]

    for f in file_or_files:
        assert isinstance(f, io.IOBase)

        for line in f:
            assert(isinstance(line, str))

            line = line.strip()

            if not line:
                continue

            topic_id, terms = line.split(delimiter, 1)

            if topic_id in topics and (topics[topic_id] != terms):
                    logging.error('Duplicate topic "%s" (%s vs. %s).',
                                  topic_id,
                                  topics[topic_id],
                                  terms)

            topics[topic_id] = terms

            if max_topics > 0 and len(topics) >= max_topics:
                break

    return topics

# with open('./ap_88_89/topics_title', 'r') as f_topics:
#     print(parse_topics([f_topics]))

# %% [markdown]
# # Information Retrieval I #
# ## Answers for Task 2: retrieval models [100 points + 10 bonus points] ##
# **TA**: Christophe Van Gysel (cvangysel@uva.nl; C3.258B, Science Park 904)
#
# **Students: Fije van Overeem (10373535) and Diede Rusticus (1090486)**
#
# To (re-)train models, uncomment the line of code where model is called.
#
# Table Of Contents
#
# 1) Word2Vec
#
# a) connector class
# b) representation of query and documents
# c) rerank task 1's tf-idf ranking based on cosine similarity
#
# 2) LSI
#
# a) connector class
# b) representation of query and documents
# c) rerank task 1's tf-idf ranking based on cosine similarity
#
# 3) LDA
#
# a) connector class
# b) representation of query and documents
# c) rerank task 1's tf-idf ranking based on cosine similarity
#
# 4) Doc2Vec
#
# a) connector class
# b) representation of query and documents
# c) rerank task 1's tf-idf ranking based on cosine similarity
#
# NB: t-testing is done in significance testing iPython-file.

# %%
token2id, id2token, _ = index.get_dictionary()
#print(list(id2token.items())[:15])

# %%
query_tokens = index.tokenize("University of Massachusetts")
print("Query by tokens:", query_tokens)
query_id_tokens = [token2id.get(query_token,0) for query_token in query_tokens]
print("Query by ids with stopwords:", query_id_tokens)
query_id_tokens = [word_id for word_id in query_id_tokens if word_id > 0]
print("Query by ids without stopwords:", query_id_tokens)
print(token2id.get('university'))
# Out:
# Query by tokens: ['university', '', 'massachusetts']
# Query by ids with stopwords: [200, 0, 894]
# Query by ids without stopwords: [200, 894]
# 200

# %% [markdown]
# ## Word2Vec ##

# %% [markdown]
# ### Connector class for word2vec as provided by assignment.###

# %%
word2vec_init = gensim.models.Word2Vec(
    size=64,  # Embedding size - initially 300
    window=5,  # One-sided window size, init was 5
    sg=True,  # Skip-gram.
    min_count=1,  # Minimum word frequency.
    sample=1e-3,  # Sub-sample threshold.
    hs=False,  # Hierarchical softmax.
    negative=10,  # Number of negative examples.
    iter=1,  # Number of iterations.
    workers=8,  # Number of workers.
)

dictionary = pyndri.extract_dictionary(index)
start = time.time()
sentences = pyndri.compat.IndriSentences(index, dictionary, max_documents=50000) # max_documents due to time complexity

logging.info('Constructing word2vec vocabulary.')

# Build vocab.
word2vec_init.build_vocab(sentences, trim_rule=None)

models = [word2vec_init]
print('going in epoch')
for epoch in range(1, 5+1):#range(1, 5 + 1):
    start = time.time()
    logging.info('Epoch %d', epoch)
    model = copy.deepcopy(models[-1])
    model.train(sentences)

    models.append(model)
    print(time.time()-start)
logging.info('Trained models: %s', models)
#print(models[-1]) # last model is most advanced
models[-1].save('Small_Morning_Run')
# Out:
# INFO:root:Constructing word2vec vocabulary.
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 2607270 words, keeping 73866 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 5208413 words, keeping 101162 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 7779447 words, keeping 121185 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 10402346 words, keeping 138774 word types
# INFO:gensim.models.word2vec:collected 153153 word types from a corpus of 12981963 raw words and 50000 sentences
# INFO:gensim.models.word2vec:Loading a fresh vocabulary
# INFO:gensim.models.word2vec:min_count=1 retains 153153 unique words (100% of original 153153, drops 0)
# INFO:gensim.models.word2vec:min_count=1 leaves 12981963 word corpus (100% of original 12981963, drops 0)
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 153153 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 10 most-common words
# INFO:gensim.models.word2vec:downsampling leaves estimated 12932354 word corpus (99.6% of prior 12981963)
# INFO:gensim.models.word2vec:estimated required memory for 153153 words and 64 dimensions: 154990836 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:root:Epoch 1
# going in epoch
# INFO:gensim.models.word2vec:training model with 8 workers on 153153 vocabulary and 64 features, using sg=1 hs=False sample=0.001 negative=10 window=5
# INFO:gensim.models.word2vec:expecting 50000 sentences, matching count from corpus used for vocabulary survey
# INFO:gensim.models.word2vec:PROGRESS: at 0.07% examples, 7241 words/s, in_qsize 2, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 0.54% examples, 26169 words/s, in_qsize 0, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 0.92% examples, 29066 words/s, in_qsize 3, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 1.33% examples, 32711 words/s, in_qsize 4, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 1.64% examples, 30163 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 2.21% examples, 33532 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 2.84% examples, 35338 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 3.44% examples, 36384 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.03% examples, 37689 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.45% examples, 38791 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.66% examples, 37716 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 5.20% examples, 37954 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 5.58% examples, 38226 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 5.90% examples, 37811 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 6.37% examples, 38780 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 6.64% examples, 38466 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.02% examples, 38815 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.32% examples, 39146 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.66% examples, 38316 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.99% examples, 38687 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 8.29% examples, 38619 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 8.77% examples, 39061 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.14% examples, 39342 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.37% examples, 38958 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.55% examples, 37964 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 10.02% examples, 38306 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 10.18% examples, 37612 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 10.70% examples, 37934 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 11.21% examples, 38460 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 11.53% examples, 38256 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 11.90% examples, 37646 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.39% examples, 38063 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.54% examples, 37595 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.87% examples, 37675 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.10% examples, 37482 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.45% examples, 37666 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.77% examples, 37561 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.93% examples, 37213 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.22% examples, 37095 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.65% examples, 37331 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 14.87% examples, 37149 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.28% examples, 37346 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.43% examples, 36826 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.98% examples, 37378 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 16.14% examples, 36866 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 16.68% examples, 37110 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 16.91% examples, 36886 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 17.31% examples, 36806 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 17.62% examples, 36836 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 17.90% examples, 36680 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 18.33% examples, 36911 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 18.75% examples, 36546 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 19.13% examples, 36696 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 19.29% examples, 36413 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 19.51% examples, 36288 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 19.84% examples, 36317 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.21% examples, 36493 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.42% examples, 36383 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.65% examples, 36403 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.95% examples, 36365 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 21.35% examples, 36432 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 21.59% examples, 36300 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 21.81% examples, 36192 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 22.20% examples, 36141 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 22.73% examples, 36392 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 23.05% examples, 36334 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 23.45% examples, 36328 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 23.66% examples, 36207 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.14% examples, 36398 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.59% examples, 36498 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.81% examples, 36415 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 25.11% examples, 36386 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 25.41% examples, 36353 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 25.72% examples, 36324 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.00% examples, 36266 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.14% examples, 36031 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.51% examples, 36099 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.76% examples, 35965 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 27.24% examples, 36135 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 27.45% examples, 36006 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 27.93% examples, 36140 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.09% examples, 35974 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.56% examples, 36117 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.86% examples, 36140 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 29.14% examples, 36092 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 29.50% examples, 36150 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 29.76% examples, 36073 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 30.16% examples, 36096 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 30.49% examples, 36025 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 30.97% examples, 36201 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.11% examples, 36034 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.57% examples, 36177 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.79% examples, 35981 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 32.24% examples, 36065 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 32.55% examples, 36071 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 32.83% examples, 36010 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 33.02% examples, 35810 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 33.46% examples, 35935 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 33.67% examples, 35864 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.08% examples, 35951 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.27% examples, 35896 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.69% examples, 35926 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.85% examples, 35749 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 35.24% examples, 35806 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 35.46% examples, 35727 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 35.93% examples, 35858 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 36.21% examples, 35850 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 36.58% examples, 35883 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.13% examples, 36036 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.32% examples, 35960 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.56% examples, 35905 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.91% examples, 35989 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 38.26% examples, 36057 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 38.58% examples, 36062 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 38.92% examples, 35999 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 39.30% examples, 36079 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 39.53% examples, 36030 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 40.04% examples, 36140 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 40.30% examples, 36067 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 40.77% examples, 36051 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.16% examples, 36095 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.40% examples, 36046 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.88% examples, 36182 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 42.09% examples, 36133 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 42.58% examples, 36152 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.15% examples, 36317 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.47% examples, 36277 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.85% examples, 36282 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 44.40% examples, 36418 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 44.70% examples, 36405 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.06% examples, 36419 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.59% examples, 36566 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.88% examples, 36553 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 46.24% examples, 36446 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 46.78% examples, 36551 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 47.09% examples, 36510 words/s, in_qsize 14, out_qsize 2
# INFO:gensim.models.word2vec:PROGRESS: at 47.46% examples, 36445 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 47.97% examples, 36602 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 48.06% examples, 36426 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 48.63% examples, 36557 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 48.71% examples, 36394 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.30% examples, 36451 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 49.61% examples, 36464 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.93% examples, 36241 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.51% examples, 36242 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.12% examples, 36212 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.64% examples, 36384 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.72% examples, 36235 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.34% examples, 36323 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.96% examples, 36399 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.33% examples, 36438 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.59% examples, 36245 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.89% examples, 36254 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.22% examples, 36162 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.67% examples, 36275 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.86% examples, 36049 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.34% examples, 36189 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.48% examples, 36092 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 56.02% examples, 36178 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.62% examples, 36163 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.16% examples, 36320 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.25% examples, 36089 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.76% examples, 36184 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.93% examples, 36084 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.44% examples, 36186 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.51% examples, 36045 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.91% examples, 36080 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.22% examples, 36038 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.74% examples, 36072 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.10% examples, 36111 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.41% examples, 36060 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.96% examples, 36086 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.36% examples, 36117 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.66% examples, 36079 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.17% examples, 36189 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.55% examples, 36245 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.84% examples, 36230 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.40% examples, 36324 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.61% examples, 36290 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.99% examples, 36340 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.36% examples, 36378 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.60% examples, 36382 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.10% examples, 36468 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.43% examples, 36477 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.73% examples, 36479 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.96% examples, 36387 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.33% examples, 36436 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.57% examples, 36395 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.94% examples, 36410 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.24% examples, 36394 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.52% examples, 36405 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.75% examples, 36365 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.06% examples, 36322 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.20% examples, 36219 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.59% examples, 36270 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.80% examples, 36202 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.28% examples, 36254 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.56% examples, 36249 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 69.97% examples, 36257 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.43% examples, 36338 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.65% examples, 36302 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.11% examples, 36389 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.35% examples, 36355 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.81% examples, 36380 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.35% examples, 36476 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.68% examples, 36464 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.07% examples, 36458 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.62% examples, 36524 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.15% examples, 36619 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.38% examples, 36559 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.88% examples, 36609 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.37% examples, 36701 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.51% examples, 36611 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.02% examples, 36650 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.41% examples, 36679 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.68% examples, 36675 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.22% examples, 36750 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.51% examples, 36756 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.95% examples, 36789 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 78.40% examples, 36870 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 78.70% examples, 36878 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.14% examples, 36912 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.58% examples, 36975 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.97% examples, 37005 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 80.30% examples, 37041 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 80.76% examples, 37083 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 81.10% examples, 37114 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 81.51% examples, 37171 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 81.90% examples, 37186 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 82.33% examples, 37246 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 82.73% examples, 37284 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 83.09% examples, 37292 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 83.55% examples, 37350 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.01% examples, 37343 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.39% examples, 37323 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.63% examples, 37076 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.96% examples, 37057 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 85.18% examples, 37008 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 85.55% examples, 36981 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 85.88% examples, 36963 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.26% examples, 37001 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.46% examples, 36923 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.78% examples, 36882 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.07% examples, 36725 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.46% examples, 36762 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.69% examples, 36707 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.99% examples, 36684 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 88.31% examples, 36672 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 88.60% examples, 36679 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 88.92% examples, 36650 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 89.30% examples, 36681 words/s, in_qsize 13, out_qsize 2
# INFO:gensim.models.word2vec:PROGRESS: at 89.71% examples, 36692 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 90.19% examples, 36700 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 90.55% examples, 36733 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 90.87% examples, 36722 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.16% examples, 36681 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.49% examples, 36676 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.80% examples, 36682 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 92.04% examples, 36641 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 92.41% examples, 36641 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 92.62% examples, 36615 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.08% examples, 36664 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.47% examples, 36691 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.90% examples, 36693 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.42% examples, 36783 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.48% examples, 36694 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.87% examples, 36730 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 95.09% examples, 36695 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 95.63% examples, 36785 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 95.91% examples, 36781 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.33% examples, 36786 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.70% examples, 36782 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.94% examples, 36745 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.33% examples, 36775 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.59% examples, 36741 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.99% examples, 36731 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 98.22% examples, 36688 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 98.59% examples, 36716 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 98.91% examples, 36722 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 99.42% examples, 36738 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:training on 12981963 raw words (12932441 effective words) took 350.9s, 36853 effective words/s
# INFO:root:Epoch 2
# 384.2206084728241
# INFO:gensim.models.word2vec:training model with 8 workers on 153153 vocabulary and 64 features, using sg=1 hs=False sample=0.001 negative=10 window=5
# INFO:gensim.models.word2vec:expecting 50000 sentences, matching count from corpus used for vocabulary survey
# INFO:gensim.models.word2vec:PROGRESS: at 0.07% examples, 5117 words/s, in_qsize 2, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 0.47% examples, 19394 words/s, in_qsize 2, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 0.69% examples, 21101 words/s, in_qsize 5, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 1.18% examples, 27177 words/s, in_qsize 7, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 1.49% examples, 28906 words/s, in_qsize 9, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 1.82% examples, 31121 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 2.21% examples, 33197 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 2.50% examples, 32834 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 2.99% examples, 34655 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 3.35% examples, 35530 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 3.72% examples, 35814 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.18% examples, 36889 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.45% examples, 36950 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 4.90% examples, 37273 words/s, in_qsize 15, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 5.36% examples, 38312 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 5.66% examples, 37914 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 6.12% examples, 38678 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 6.57% examples, 39178 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 6.86% examples, 38796 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.27% examples, 39425 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.71% examples, 39692 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 7.99% examples, 39345 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 8.46% examples, 39863 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 8.62% examples, 38330 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.07% examples, 38896 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.46% examples, 39113 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 9.85% examples, 39010 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 10.34% examples, 39555 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 10.76% examples, 39865 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 11.07% examples, 39636 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 11.53% examples, 40021 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.00% examples, 40353 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.31% examples, 39619 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 12.72% examples, 40034 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.17% examples, 40381 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.30% examples, 39706 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.46% examples, 39155 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 13.82% examples, 39297 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.02% examples, 38330 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.42% examples, 38426 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.58% examples, 37631 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 14.87% examples, 37503 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.12% examples, 36924 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.22% examples, 36019 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 15.76% examples, 36464 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 16.05% examples, 36452 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 16.44% examples, 36320 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 17.08% examples, 36616 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 17.62% examples, 37138 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 17.90% examples, 36751 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 18.24% examples, 36609 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 18.75% examples, 36948 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 18.97% examples, 36810 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 19.51% examples, 36939 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.13% examples, 37149 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 20.65% examples, 37397 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 21.28% examples, 37610 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 21.90% examples, 37853 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 22.34% examples, 38123 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 22.82% examples, 38276 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 23.14% examples, 38217 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 23.66% examples, 38563 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.06% examples, 38640 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.35% examples, 38595 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 24.81% examples, 38821 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 25.18% examples, 38927 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 25.57% examples, 38899 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.07% examples, 39152 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.45% examples, 39248 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 26.76% examples, 39177 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 27.31% examples, 39409 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 27.69% examples, 39497 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.01% examples, 39459 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.56% examples, 39673 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 28.98% examples, 39733 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 29.34% examples, 39785 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 29.84% examples, 39840 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 30.33% examples, 40005 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 30.79% examples, 40113 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.11% examples, 40063 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.57% examples, 40226 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 31.94% examples, 40289 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 32.32% examples, 40266 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 32.83% examples, 40422 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 33.31% examples, 40529 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 33.62% examples, 40471 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.08% examples, 40594 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.43% examples, 40660 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 34.78% examples, 40638 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 35.33% examples, 40772 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 35.61% examples, 40752 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 36.01% examples, 40819 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 36.45% examples, 40913 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 36.71% examples, 40875 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.13% examples, 40786 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.55% examples, 40930 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 37.91% examples, 40963 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 38.26% examples, 40954 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 38.71% examples, 41091 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 39.08% examples, 41087 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 39.45% examples, 41082 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 39.97% examples, 41249 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 40.31% examples, 41224 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 40.69% examples, 41203 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.16% examples, 41339 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.48% examples, 41312 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 41.88% examples, 41327 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 42.36% examples, 41435 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 42.74% examples, 41469 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.15% examples, 41474 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.55% examples, 41529 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 43.85% examples, 41498 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 44.40% examples, 41596 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 44.70% examples, 41544 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.06% examples, 41511 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.59% examples, 41612 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 45.88% examples, 41586 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 46.24% examples, 41616 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 46.78% examples, 41730 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 47.08% examples, 41699 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 47.46% examples, 41736 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 47.97% examples, 41823 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 48.37% examples, 41854 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 48.71% examples, 41808 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.23% examples, 41940 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.61% examples, 41954 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.93% examples, 41895 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.45% examples, 42058 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.73% examples, 42039 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.12% examples, 41981 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.72% examples, 42027 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.34% examples, 42069 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.96% examples, 42115 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.59% examples, 42167 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.22% examples, 42224 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.86% examples, 42271 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.41% examples, 42315 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.02% examples, 42352 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.62% examples, 42399 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.25% examples, 42441 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.85% examples, 42491 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.51% examples, 42525 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.14% examples, 42551 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.74% examples, 42599 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.34% examples, 42616 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.96% examples, 42636 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.58% examples, 42685 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.17% examples, 42702 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.77% examples, 42736 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 63.40% examples, 42771 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.99% examples, 42814 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.54% examples, 42873 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.10% examples, 42910 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.73% examples, 42958 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.33% examples, 42985 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.94% examples, 43031 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.48% examples, 43157 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.61% examples, 43011 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.11% examples, 43090 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.66% examples, 43205 words/s, in_qsize 13, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.80% examples, 43059 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.35% examples, 43153 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.83% examples, 43252 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.97% examples, 43120 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.49% examples, 43235 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.73% examples, 43161 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.19% examples, 43185 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.72% examples, 43274 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.04% examples, 43216 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.44% examples, 43238 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.91% examples, 43297 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.18% examples, 43247 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.62% examples, 43280 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.10% examples, 43340 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.38% examples, 43289 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.88% examples, 43326 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.32% examples, 43367 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.59% examples, 43335 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.18% examples, 43312 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.76% examples, 43413 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.36% examples, 43454 words/s, in_qsize 15, out_qsize 0
# ...
# INFO:gensim.models.word2vec:PROGRESS: at 48.71% examples, 35416 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.15% examples, 35536 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.53% examples, 35555 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 49.87% examples, 35516 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.15% examples, 35501 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.45% examples, 35446 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 50.73% examples, 35438 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.06% examples, 35442 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.36% examples, 35442 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 51.72% examples, 35442 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.03% examples, 35325 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.51% examples, 35411 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 52.83% examples, 35427 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.04% examples, 35389 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.33% examples, 35403 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.74% examples, 35469 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 53.97% examples, 35435 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.38% examples, 35468 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 54.67% examples, 35467 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.01% examples, 35485 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.27% examples, 35458 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 55.57% examples, 35472 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 55.73% examples, 35320 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.02% examples, 35336 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.36% examples, 35248 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.79% examples, 35325 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 56.95% examples, 35232 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.40% examples, 35334 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 57.64% examples, 35280 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.11% examples, 35300 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.20% examples, 35167 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.66% examples, 35273 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 58.82% examples, 35179 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.29% examples, 35260 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.44% examples, 35165 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 59.85% examples, 35218 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.10% examples, 35191 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.47% examples, 35233 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 60.88% examples, 35244 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.20% examples, 35261 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.43% examples, 35234 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 61.73% examples, 35176 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 62.10% examples, 35213 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.38% examples, 35217 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 62.69% examples, 35229 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.08% examples, 35223 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.54% examples, 35295 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 63.78% examples, 35267 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.23% examples, 35343 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.54% examples, 35388 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 64.84% examples, 35368 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.27% examples, 35415 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.65% examples, 35454 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 65.96% examples, 35466 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.41% examples, 35561 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 66.64% examples, 35512 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.10% examples, 35542 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.42% examples, 35555 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 67.75% examples, 35595 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.06% examples, 35601 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.42% examples, 35638 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 68.87% examples, 35673 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.20% examples, 35673 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.56% examples, 35727 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 69.83% examples, 35705 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.28% examples, 35742 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.65% examples, 35792 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 70.88% examples, 35761 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.28% examples, 35774 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 71.65% examples, 35773 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.04% examples, 35814 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.44% examples, 35846 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 72.77% examples, 35843 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.13% examples, 35873 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.41% examples, 35882 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 73.77% examples, 35888 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.15% examples, 35928 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.45% examples, 35928 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 74.80% examples, 35940 words/s, in_qsize 14, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 75.18% examples, 35969 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.51% examples, 36009 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 75.81% examples, 36019 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.18% examples, 36026 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.49% examples, 36024 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 76.84% examples, 36036 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.29% examples, 36097 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.57% examples, 36101 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 77.95% examples, 36119 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 78.26% examples, 36125 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 78.63% examples, 36131 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.06% examples, 36197 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.31% examples, 36169 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 79.71% examples, 36198 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 80.11% examples, 36210 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 80.37% examples, 36217 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 80.76% examples, 36255 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 81.02% examples, 36261 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 81.33% examples, 36271 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 81.67% examples, 36293 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 82.05% examples, 36317 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 82.43% examples, 36321 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 82.81% examples, 36334 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 83.09% examples, 36340 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 83.47% examples, 36367 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 83.94% examples, 36388 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.33% examples, 36401 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.63% examples, 36410 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 84.96% examples, 36414 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 85.32% examples, 36453 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 85.72% examples, 36491 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.02% examples, 36471 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.40% examples, 36496 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 86.78% examples, 36501 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.15% examples, 36524 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.54% examples, 36554 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 87.82% examples, 36550 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 88.24% examples, 36563 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 88.60% examples, 36570 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 89.00% examples, 36602 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 89.30% examples, 36588 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 89.79% examples, 36643 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 90.19% examples, 36648 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 90.48% examples, 36646 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 90.87% examples, 36671 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.16% examples, 36664 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.63% examples, 36723 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 91.88% examples, 36695 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 92.33% examples, 36724 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 92.68% examples, 36742 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.00% examples, 36741 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.40% examples, 36769 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 93.74% examples, 36759 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.17% examples, 36796 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.48% examples, 36801 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 94.87% examples, 36808 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 95.25% examples, 36829 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 95.54% examples, 36823 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.01% examples, 36858 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.24% examples, 36830 words/s, in_qsize 16, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 96.70% examples, 36874 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.02% examples, 36881 words/s, in_qsize 14, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.41% examples, 36878 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 97.92% examples, 36908 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 98.22% examples, 36898 words/s, in_qsize 16, out_qsize 1
# INFO:gensim.models.word2vec:PROGRESS: at 98.67% examples, 36922 words/s, in_qsize 15, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 99.10% examples, 36972 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:PROGRESS: at 99.42% examples, 36963 words/s, in_qsize 8, out_qsize 0
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 7 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 6 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 5 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 4 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 3 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 2 more threads
# INFO:gensim.models.word2vec:PROGRESS: at 99.92% examples, 37036 words/s, in_qsize 1, out_qsize 1
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 1 more threads
# INFO:gensim.models.word2vec:worker thread finished; awaiting finish of 0 more threads
# INFO:gensim.models.word2vec:training on 12981963 raw words (12932382 effective words) took 349.0s, 37060 effective words/s
# INFO:root:Trained models: [<gensim.models.word2vec.Word2Vec object at 0x7fd88397c160>, <gensim.models.word2vec.Word2Vec object at 0x7fd90022df98>, <gensim.models.word2vec.Word2Vec object at 0x7fd88244ed68>, <gensim.models.word2vec.Word2Vec object at 0x7fd8d7112f98>, <gensim.models.word2vec.Word2Vec object at 0x7fd8e6ca41d0>, <gensim.models.word2vec.Word2Vec object at 0x7fd8d7a1a470>]
# INFO:gensim.utils:saving Word2Vec object under Small_Morning_Run, separately None
# INFO:gensim.utils:not storing attribute cum_table
# INFO:gensim.utils:not storing attribute syn0norm
# 356.14865922927856
# INFO:gensim.utils:saved Small_Morning_Run

# %%
# Load your Word2Vec model
savedW2Vmodel = gensim.models.Word2Vec.load('Small_Morning_Run')
# Out:
# INFO:gensim.utils:loading Word2Vec object from Small_Morning_Run
# INFO:gensim.utils:loading wv recursively from Small_Morning_Run.wv.* with mmap=None
# INFO:gensim.utils:loading docvecs recursively from Small_Morning_Run.docvecs.* with mmap=None
# INFO:gensim.utils:setting ignored attribute cum_table to None
# INFO:gensim.utils:setting ignored attribute syn0norm to None
# INFO:gensim.utils:loaded Small_Morning_Run
# Doc2Vec(dbow,d100,n10,s0.001,t8)

# %% [markdown]
# ### Build representation for q and d ###

# %%
# Takes average of all query terms in 1 query, so the query is represented by 1 vector
def get_q_rep(index, query_str, w2vmodel):
    query_tokens = index.tokenize(query_str)
    vectors = []
    for token in query_tokens:
        vector = w2vmodel['token']
        vectors.append(vector)

    avg_query = np.mean(np.array(vectors), axis=0)
    return avg_query

# Takes average of all terms in 1 document, so the document is represented by 1 vector
def get_d_rep(document, w2vmodel):
    wordIDs = document[1][:]
    vectors = []
    for wordID in wordIDs:
        if wordID > 0:
            wordstring = id2token[wordID]
            if wordstring in w2vmodel:
                vector = w2vmodel[wordstring]
                vectors.append(vector)

    avg_doc = np.mean(np.array(vectors), axis=0)
    return avg_doc

#avg_d = get_d_rep(index.document(1),savedW2Vmodel)
#mutual_info_score(avg_q, avg_d)
# Out:
# 0.348099537217
# 0.65190053

# %% [markdown]
# ### Check cosine similarity between a word2vec-query representation and a (word2vec-representation) of set of documents.###

# %%
def check_cosine_given_query(avg_q, queryID, internal_docIDs):
    word2vec_dict = {}
    for internal_docID in internal_docIDs: # amount of documents
        avg_d = get_d_rep(index.document(internal_docID),savedW2Vmodel)
        cosine = cosine_similarity(numpy.reshape(avg_q, (1, -1)),  numpy.reshape(avg_d, (1, -1)))[0][0] 
        external_ID = index.document(internal_docID)[0]
        word2vec_dict[external_ID] = cosine
    return word2vec_dict

# %%
def make_dict_format(dic):
    results = []
    for doc, score in dic.items():
        results.append((score, doc))
    return tuple(results)

# %% [markdown]
# ### Rerank documents for queries of TF-IDFs with word2vec model. ###

# %%
def check_cosine_all_queries(tfidf_rankings):
    dic = {}
    for query_id, ranked_docs in tfidf_rankings.items():
        query_string = query_dict[str(query_id)]
        avg_q = get_q_rep(index, query_string, savedW2Vmodel)
        cosines_per_q = check_cosine_given_query(avg_q, query_id, ranked_docs)
        dic[query_id] = make_dict_format(cosines_per_q)
    return dic

new_rankings = check_cosine_all_queries(tfidf_rankings)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-133-4a9a5de506a7> in <module>()
#       8     return dic
#       9
# ---> 10 new_rankings = check_cosine_all_queries(tfidf_rankings)
#
# <ipython-input-133-4a9a5de506a7> in check_cosine_all_queries(tfidf_rankings)
#       3     for query_id, ranked_docs in tfidf_rankings.items():
#       4         query_string = query_dict[str(query_id)]
# ----> 5         avg_q = get_q_rep(index, query_string, savedW2Vmodel)
#       6         cosines_per_q = check_cosine_given_query(avg_q, query_id, ranked_docs)
#       7         dic[query_id] = make_dict_format(cosines_per_q)
#
# <ipython-input-92-500197716de4> in get_q_rep(index, query_str, ldamodel)
#       3
#       4 def get_q_rep(index, query_str, ldamodel):
# ----> 5     pairs = ldamodel[dictionary.doc2bow(index.tokenize(query_str))]
#       6     weights = []
#       7     for pair in pairs:
#
# /usr/local/lib/python3.5/dist-packages/gensim/models/word2vec.py in __getitem__(self, words)
#    1301
#    1302     def __getitem__(self, words):
# -> 1303         return self.wv.__getitem__(words)
#    1304
#    1305     @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py in __getitem__(self, words)
#     348             return self.syn0[self.vocab[words].index]
#     349
# --> 350         return vstack([self.syn0[self.vocab[word].index] for word in words])
#     351
#     352     def __contains__(self, word):
#
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py in <listcomp>(.0)
#     348             return self.syn0[self.vocab[words].index]
#     349
# --> 350         return vstack([self.syn0[self.vocab[word].index] for word in words])
#     351
#     352     def __contains__(self, word):
#
# KeyError: (3066, 1)

# %% [markdown]
#  ### Connector Class between Gensim and Pyndri for LSI and LDA model ###

# %%
# Connector class for LSI and LDA model
import logging
logging.basicConfig(level=logging.INFO)
class IndriBOW(gensim.interfaces.CorpusABC):

    def __init__(self, index, dictionary, max_documents=None):
        assert isinstance(index, pyndri.Index)

        self.index = index
        self.dictionary = dictionary

        self.max_documents = max_documents

    def _maximum_document(self):
        if self.max_documents is None:
            return self.index.maximum_document()
        else:
            return min(
                self.max_documents + self.index.document_base(),
                self.index.maximum_document())

    def __iter__(self): # both used for LSI and LDI
        for int_doc_id in range(self.index.document_base(),
                                self._maximum_document()):
            ext_doc_id, tokens = self.index.document(int_doc_id)

            yield self.dictionary.doc2bow(
                self.dictionary[token_id]
                for token_id in tokens
                if token_id > 0 and token_id in self.dictionary)

    def __len__(self):
        return self._maximum_document() - self.index.document_base()

# %% [markdown]
# ### Train LSI Model ###

# %%
## Build LSI Model ##

'''LSI compares how often words appear together in the same document
and compares how often those occurences happen in all of the documents 
that the dictionary has in its index.'''

logging.getLogger().setLevel(logging.INFO)
def train_lsi():
    sentences = IndriBOW(index, dictionary)
    lsi = gensim.models.lsimodel.LsiModel(
        corpus = sentences,
        id2word = dictionary.id2token
    )
    return lsi
#lsimodel = train_lsi()
#lsimodel.save('LSI_model')

# %% [markdown]
# #### q and d representation with the lsi model so we can rank documents based on query. ####

# %%
lsimodel = gensim.models.LsiModel.load('LSI_model')

def get_q_rep(index, query_str, lsimodel):
    pairs = lsimodel[dictionary.doc2bow(index.tokenize(query_str))]
    weights = []
    for pair in pairs:
        weights.append(pair[1])
    return weights
    
__, id2token, _ = index.get_dictionary()
def get_docrep(index, doc_id):
    docrep = [id2token[word] for word in index.document(doc_id)[1] if word > 0]
    drep = lsimodel[dictionary.doc2bow(docrep)]
    weights = []
    for pair in drep:
        weights.append(pair[1])
    return weights
# Out:
# INFO:gensim.utils:loading LsiModel object from LSI_model
# INFO:gensim.utils:setting ignored attribute dispatcher to None
# INFO:gensim.utils:setting ignored attribute projection to None
# INFO:gensim.utils:loaded LSI_model
# INFO:gensim.utils:loading LsiModel object from LSI_model.projection
# INFO:gensim.utils:loading u from LSI_model.projection.u.npy with mmap=None
# INFO:gensim.utils:loaded LSI_model.projection

# %% [markdown]
# ### Check cosine similarity between query-representation for LSI and documents ###

# %%
def check_cosine_given_query_lsi(avg_q, queryID, internal_docIDs):
    lsi_dict = {}
    for internal_docID in internal_docIDs: # amount of documents
        avg_d = get_docrep(index, internal_docID)
        cosine = cosine_similarity(numpy.reshape(avg_q, (1, -1)),  numpy.reshape(avg_d, (1, -1)))[0][0] 
        external_ID = index.document(internal_docID)[0]
        lsi_dict[external_ID] = cosine
    return lsi_dict

# %% [markdown]
# ### Rerank the tf-idf 1000 rankings per query with LSI model ###

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.cluster import mutual_info_score #is equivalent to KL divergence
import numpy
def check_cosine_all_queries_lsi(tfidf_rankings):
    dic = {}
    for query_id, ranked_docs in tfidf_rankings.items():
        query_string = query_dict[str(query_id)]
        avg_q = get_q_rep(index, query_string, lsimodel)
        cosines_per_q = check_cosine_given_query_lsi(avg_q, query_id, ranked_docs)
        dic[query_id] = make_dict_format(cosines_per_q)
    return dic

#new_rankings_lsi = check_cosine_all_queries_lsi(tfidf_rankings)

# %% [markdown]
# ### Train LDA Model (uses same connector class as LSI) ###

# %%
## Latent Dirichlet Allocation ##
# Uses same connector class as LSI (doc2bow)
logging.getLogger().setLevel(logging.INFO)
def train_lda():
    sentences = IndriBOW(index, dictionary)
    lda = gensim.models.ldamodel.LdaModel(
        corpus = sentences,
        id2word = dictionary.id2token
    )
    return lda
#ldamodel = train_lda()
ldamodel.save('LDA_overnight_model')
# Out:
# INFO:gensim.utils:saving LdaState object under LDA_overnight_model.state, separately None
# INFO:gensim.utils:storing np array 'sstats' to LDA_overnight_model.state.sstats.npy
# INFO:gensim.utils:saved LDA_overnight_model.state
# INFO:gensim.utils:saving LdaModel object under LDA_overnight_model, separately ['expElogbeta', 'sstats']
# INFO:gensim.utils:not storing attribute state
# INFO:gensim.utils:not storing attribute dispatcher
# INFO:gensim.utils:not storing attribute id2word
# INFO:gensim.utils:storing np array 'expElogbeta' to LDA_overnight_model.expElogbeta.npy
# INFO:gensim.utils:saved LDA_overnight_model

# %% [markdown]
# ### Get query representation and document representation for the LDA model ###

# %%
# LDA only takes the topics where there's a probability, so the vector isn't the goal size of 200.
# We fill up the vectors with 0- probabilities for the rest of the topics 
def get_q_rep_lda(index, query_str, ldamodel):
    pairs = ldamodel[dictionary.doc2bow(index.tokenize(query_str))]
    topicnrs = []
    weights = []
    count = 0
    for pair in pairs:
        topicnrs.append(pair[0])
    for i in range(200):# goal vector size
        if i in topicnrs:
            weights.append(pairs[count][1])
            count =+ 1
        else:
            weights.append(0.0)
    return weights

__, id2token, _ = index.get_dictionary()
def get_docrep_lda(index, doc_id):
    docrep = [id2token[word] for word in index.document(doc_id)[1] if word > 0]
    drep = ldamodel[dictionary.doc2bow(docrep)]
    weights = []
    for pair in drep:
        weights.append(pair[1])
    return weights

# %% [markdown]
#  ### Check cosine similarity between query and documents for LDA representations ###

# %%
def check_cosine_given_query_lda(avg_q, queryID, internal_docIDs):
    lda_dict = {}
    for internal_docID in internal_docIDs: # amount of documents
        avg_d = get_docrep(index, internal_docID)
        cosine = cosine_similarity(numpy.reshape(avg_q, (1, -1)),  numpy.reshape(avg_d, (1, -1)))[0][0] 
        external_ID = index.document(internal_docID)[0]
        lda_dict[external_ID] = cosine
    return lda_dict

# %% [markdown]
# ### Rerank the tf-idf rankings per query based on LDA model ###

# %%
# q and d representation with the lda model so we can rank documents based on query.
ldamodel = gensim.models.LdaModel.load('LDA_overnight_model')
def check_cosine_all_queries_lda(tfidf_rankings):
    dic = {}
    for query_id, ranked_docs in tfidf_rankings.items():
        query_string = query_dict[str(query_id)]
        avg_q = get_q_rep_lda(index, query_string, ldamodel)
        cosines_per_q = check_cosine_given_query_lda(avg_q, query_id, ranked_docs)
        dic[query_id] = make_dict_format(cosines_per_q)
    return dic
Lda_rerank = check_cosine_all_queries_lda(tfidf_rankings)
# Out:
# INFO:gensim.utils:loading LdaModel object from LDA_overnight_model
# INFO:gensim.utils:loading expElogbeta from LDA_overnight_model.expElogbeta.npy with mmap=None
# INFO:gensim.utils:setting ignored attribute state to None
# INFO:gensim.utils:setting ignored attribute dispatcher to None
# INFO:gensim.utils:setting ignored attribute id2word to None
# INFO:gensim.utils:loaded LDA_overnight_model
# INFO:gensim.utils:loading LdaModel object from LDA_overnight_model.state
# INFO:gensim.utils:loading sstats from LDA_overnight_model.state.sstats.npy with mmap=None
# INFO:gensim.utils:loaded LDA_overnight_model.state

# %% [markdown]
# ## Doc2 Vec ##

# %% [markdown]
# ## Doc2Vec Connector Class##

# %%
class IndriDoc2Vec(gensim.interfaces.CorpusABC):

    def __init__(self, index, dictionary, max_documents=None):
        assert isinstance(index, pyndri.Index)

        self.index = index
        self.dictionary = dictionary

        self.max_documents = max_documents

    def _maximum_document(self):
        if self.max_documents is None:
            return self.index.maximum_document()
        else:
            return min(
                self.max_documents + self.index.document_base(),
                self.index.maximum_document())

    def __iter__(self): # Doc2Vec
        for int_doc_id in range(self.index.document_base(),
                                self._maximum_document()):
            ext_doc_id, tokens = self.index.document(int_doc_id)

            yield gensim.models.doc2vec.TaggedDocument(words =[self.dictionary[token_id]
                                                              for token_id in tokens if token_id >0
                                                               and token_id in self.dictionary],
                                                      tags = ['doc_'+str( int_doc_id) ])

    def __len__(self):
        return self._maximum_document() - self.index.document_base()

# %% [markdown]
# ## Build Doc2Vec model ##

# %%
doc2vec_init = gensim.models.doc2vec.Doc2Vec(
 #   size=size,  # Embedding size - initially 300
  #  window=window,  # One-sided window size, init was 5
    #sg=True,  # Skip-gram.
    min_count=1,  # Minimum word frequency.
    sample=1e-3,  # Sub-sample threshold.
    hs=False,  # Hierarchical softmax.
    negative=10,  # Number of negative examples.
    iter=1,  # Number of iterations.
    workers=8,  # Number of workers.
    dm_mean=None, 
    dm=10, 
    dbow_words=0, 
    dm_concat=0, 
)

dictionary = pyndri.extract_dictionary(index)
start = time.time()
sentences = IndriDoc2Vec(index, dictionary) # max_documents due to time complexity
#print('initialised sentences')
#print(time.time()-start)

logging.info('Constructing doc2vec vocabulary.')

# Build vocab.
doc2vec_init.build_vocab(sentences, trim_rule=None)

models = [doc2vec_init]

for epoch in range(1, 3+1):# init range(1, 5 + 1). Takes much time. Better would be at least 15 epochs.
    logging.info('Epoch %d', epoch)
    model = copy.deepcopy(models[-1])
    model.train(sentences)
    models.append(model)
    
logging.info('Trained models: %s', models)
#print(models[-1]) # last model is most advanced
models[-1].save('doc2vec_Alldocs_32LV')
savedD2Vmodel = gensim.models.Doc2Vec.load('doc2vec_Alldocs_32LV')
#print(savedD2Vmodel)

#Doc2Vec_model = gensim.models.Doc2Vec(sentences, size=32, window=8, min_count=5, workers=4)
#savedD2Vmodel.syn0[0]
#savedD2Vmodel.most_similar()
# Out:
# 967.7279672622681
# WARNING:gensim.models.word2vec:direct access to syn0 will not be supported in future gensim releases, please use model.wv.syn0
# array([-0.00374502,  0.00308837, -0.00472419, -0.00193337, -0.00035506,
#        -0.00016074,  0.00098103,  0.00092244, -0.00118338, -0.00332338,
#        -0.0013285 ,  0.00133657,  0.00192708,  0.00192939,  0.00342257,
#        -0.00439199,  0.00283154,  0.00358476, -0.00412811, -0.00191401,
#        -0.00284428,  0.00235222, -0.00356911,  0.0018685 , -0.00344937,
#        -0.00368249,  0.00289228,  0.00340447,  0.00430199,  0.00477111,
#         0.00151259, -0.00288733, -0.00170883, -0.00153607,  0.00459886,
#        -0.00419869,  0.0047371 , -0.00303401, -0.00194053,  0.00410392,
#         0.00484982, -0.00267162,  0.0042858 ,  0.00018068, -0.00444503,
#        -0.00353812,  0.00084476,  0.00319608, -0.0039742 , -0.0008061 ,
#         0.00390346,  0.00032077,  0.00438578, -0.00069475, -0.00272398,
#        -0.00450479, -0.0021173 , -0.00016915,  0.00370967,  0.00117157,
#         0.00237067,  0.00239566,  0.00377652, -0.0041114 , -0.00108679,
#        -0.00439702, -0.00441423,  0.00058906,  0.00354364,  0.00092692,
#         0.00244317, -0.00368617,  0.00180463, -0.00372343, -0.00252296,
#        -0.00340841,  0.00230748,  0.00079611, -0.00305702,  0.00188359,
#         0.00185978,  0.00447161, -0.00031207,  0.00129054,  0.00429968,
#        -0.00305045,  0.00141028,  0.00276904, -0.00467085,  0.00391484,
#        -0.0012575 , -0.00376079,  0.00443104,  0.00344112,  0.00232085,
#        -0.00357381,  0.00369912,  0.00457491,  0.0020139 ,  0.00143965], dtype=float32)

# %% [markdown]
# ### Get query rep for doc2vec ###

# %%
def get_q_rep(index, query_str, d2vmodel):
    query_tokens = index.tokenize(query_str) # " hoi ik ben diede " = "hoi", "ik...
    vectors = []
    for token in query_tokens:
        vector = d2vmodel['token']
        vectors.append(vector)

    avg_query = np.mean(np.array(vectors), axis=0)
    return avg_query

# %% [markdown]
# ### Get cosine similarity between query and document ###

# %%
def check_cosine_given_query(avg_q, queryID, internal_docIDs):
    word2vec_dict = {}
    for internal_docID in internal_docIDs: # amount of documents
        avg_d = savedD2Vmodel.docvecs[internal_docID]
        cosine = cosine_similarity(numpy.reshape(avg_q, (1, -1)),  numpy.reshape(avg_d, (1, -1)))[0][0] 
        external_ID = index.document(internal_docID)[0]
        doc2vec_dict[external_ID] = cosine
    return doc2vec_dict

# %% [markdown]
# ### Rerank TFIDF with doc2vec ###

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.cluster import mutual_info_score #is equivalent to KL divergence
import numpy
def check_cosine_all_queries(tfidf_rankings):
    dic = {}
    for query_id, ranked_docs in tfidf_rankings.items():
        query_string = query_dict[str(query_id)]
        avg_q = get_q_rep(index, query_string, savedD2Vmodel)
        cosines_per_q = check_cosine_given_query(avg_q, query_id, ranked_docs)
        dic[query_id] = make_dict_format(cosines_per_q)
    return dic

new_rankings_doc2vec = check_cosine_all_queries(tfidf_rankings)

# %% [markdown]
# ### With this code we took all rerankings and write run-files so we can evaluate. ###

# %%
def write_run(model_name, data, out_f,
              max_objects_per_query=sys.maxsize,
              skip_sorting=False):
    """
    Write a run to an output file.
    Parameters:
        - model_name: identifier of run.
        - data: dictionary mapping topic_id to object_assesments;
            object_assesments is an iterable (list or tuple) of
            (relevance, object_id) pairs.
            The object_assesments iterable is sorted by decreasing order.
        - out_f: output file stream.
        - max_objects_per_query: cut-off for number of objects per query.
    """
    for subject_id, object_assesments in data.items():
        if not object_assesments:
            logging.warning('Received empty ranking for %s; ignoring.',
                            subject_id)

            continue

        # Probe types, to make sure everything goes alright.
        # assert isinstance(object_assesments[0][0], float) or \
        #     isinstance(object_assesments[0][0], np.float32)
        assert isinstance(object_assesments[0][1], str) or \
            isinstance(object_assesments[0][1], bytes)

        if not skip_sorting:
            object_assesments = sorted(object_assesments, reverse=True)

        if max_objects_per_query < sys.maxsize:
            object_assesments = object_assesments[:max_objects_per_query]

        if isinstance(subject_id, bytes):
            subject_id = subject_id.decode('utf8')

        for rank, (relevance, object_id) in enumerate(object_assesments):
            if isinstance(object_id, bytes):
                object_id = object_id.decode('utf8')

            out_f.write(
                '{subject} Q0 {object} {rank} {relevance} '
                '{model_name}\n'.format(
                    subject=subject_id,
                    object=object_id,
                    rank=rank + 1,
                    relevance=relevance,
                    model_name=model_name))
            
# The following writes the run to standard output.
# In your code, you should write the runs to local
# storage in order to pass them to trec_eval.
# write_run(
#     model_name='lda',
#     data=Lda_rerank,
#     out_f=open('tfidf_lda.run', 'w'),
#     max_objects_per_query=1000)
